# %% [markdown]
# <a href="https://colab.research.google.com/github/adityaraute/All-About-Open-Source/blob/main/DefiLlama_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Get data from DeFiLlama

# %%
import requests
import pprint

# %%
  # Import the requests library

url = ('https://api.llama.fi/protocols')
print(url)

response = requests.get(url)  # Make a GET request to the URL

# Print status code (and associated text)
print(f"Request returned {response.status_code} : '{response.reason}'")
# Out:
# https://api.llama.fi/protocols
# Request returned 200 : 'OK'

# %%
# Print data returned (parsing as JSON)
payload = response.json()  # Parse `response.text` into JSON

pp = pprint.PrettyPrinter(indent=1)
pp.pprint(payload)
print(url)
# Out:
# Streaming output truncated to the last 5000 lines.
#   'forkedFrom': ['Tomb Finance'],
#   'gecko_id': None,
#   'id': '2127',
#   'listedAt': 1664190160,
#   'logo': 'https://icons.llama.fi/cowaii-cash.png',
#   'module': 'cowaii-cash/index.js',
#   'name': 'Cowaii Cash',
#   'oracles': ['TWAP'],
#   'pool2': 157.12118137434982,
#   'slug': 'cowaii-cash',
#   'staking': 7.664420806448101,
#   'symbol': 'COWAII',
#   'tokenBreakdowns': {},
#   'tvl': 0,
#   'twitter': 'CowaiiTomb',
#   'url': 'https://cowaii.cash'},
#  {'address': None,
#   'audit_note': None,
#   'audits': '0',
#   'category': 'Dexes',
#   'chain': 'Solana',
#   'chainTvls': {'Solana': 0},
#   'chains': ['Solana'],
#   'change_1d': None,
#   'change_1h': None,
#   'change_7d': None,
#   'cmcId': None,
#   'description': 'The best swap aggregator & infrastructure for Solana -  '
#                  'powering best price, token selection and UX for all users '
#                  'and devs',
#   'forkedFrom': [],
# ...
